# %% [markdown]
# 6/8/26. Trying to split the sample based on eye state AND self-report. Previous notebook only did eye state.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\tempu\\Downloads\\research\\labs\\gratton\\Arousal-Project\\splitting_sample\\iNETs-sleep-data.csv")
df.head(5)
# Out:
#                                              file  subject  session  task  \
# 0  sub-INET168_ses-4_task-rest_run-01_bold.nii.gz  INET168        4  rest
# 1  sub-INET168_ses-4_task-rest_run-02_bold.nii.gz  INET168        4  rest
# 2  sub-INET168_ses-4_task-rest_run-03_bold.nii.gz  INET168        4  rest
# 3  sub-INET168_ses-4_task-rest_run-04_bold.nii.gz  INET168        4  rest
# 4  sub-INET168_ses-4_task-rest_run-05_bold.nii.gz  INET168        4  rest
#
#    run notes  sleep-score FD-hold category
# 0    1   NaN            1     NaN      NaN
# 1    2   NaN            1     NaN      NaN
# 2    3   NaN            1     NaN      NaN
# 3    4   NaN            2     NaN      NaN
# 4    5   NaN            2     NaN      NaN

# %% [markdown]
# FD-hold is NaN because it's missing. Where do I get the FD info?

# %%
df_low = df[((df["sleep-score"] < 3) | (df["category"] == "eyes_closed")) & ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12964\56677794.py in ?()
# ----> 1 df_low = df[(df.sleep-score < 3) | df.category == "eyes_closed"]
#
# c:\Users\tempu\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sleep'
